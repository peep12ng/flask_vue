# %%
from backend.app.api.collecter import Collecter

# %%
# KR_6507945828

# %%
c = Collecter()

# %%
mdto = c.get_matchDto('KR_6507945828')

# %%
mdto['info']
# Out:
# {'gameCreation': 1684787519289,
#  'gameDuration': 1077,
#  'gameEndTimestamp': 1684788639805,
#  'gameId': 6507945828,
#  'gameMode': 'ARAM',
#  'gameName': 'teambuilder-match-6507945828',
#  'gameStartTimestamp': 1684787562635,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '13.10.509.8402',
#  'mapId': 12,
#  'participants': [{'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 36,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 1,
#     'abilityUses': 116,
#     'acesBefore15Minutes': 3,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 1150.2219516494388,
#     'damageTakenOnTeamPercentage': 0.18646211378606597,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 10,
# ...
